# %%
from scipy.stats import norm, uniform, binom
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
minta=binom.rvs(10,0.5,size=10000)
plt.hist(minta,density=True);
plt.plot(0,1/math.sqrt(2*math.pi),'x')

# %%
minta-
# Out:
# array([2, 4, 6, ..., 3, 1, 2])

# %%
print(1-(FI(2.5)-FI(-2.5)))
print(1-(2*FI(2.5)-1))
print(2*(1-FI(2.5)))
# Out:
# 0.012419330651552318
# 0.012419330651552318
# 0.012419330651552318

# %%
1-FI(-2)
# Out:
# 0.9772498680518208

# %%
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,4,100)
lam=0.5
ef=lambda x: lam*math.exp(-lam*x) 
plt.plot(x,[ef(v) for v in x]) 
lam=1
plt.plot(x,[ef(v) for v in x]) 
for lam in np.linspace(0.1,3,20): 
    plt.plot(x,[ef(v) for v in x])

# %%
1-1/math.exp(1)
# Out:
# 0.6321205588285577
